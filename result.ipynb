# %%
import pickle
from pprint import pprint

# %%
with open('indonlu-indobert-gs/indonlu_gs_result.pkl', 'rb') as f:
    data = pickle.load(f)

pprint(data)
# Out:
# [{'bs': 16,
#   'epoch': 5,
#   'history': {'loss': [0.5471407647908123,
#                        0.30163711124385884,
#                        0.17828176904688864,
#                        0.1190933146958355,
#                        0.09942531946504768]},
#   'lr': 2e-05,
#   'name': 'indonlu-indobert-gs-0.pkl',
#   'report': '              precision    recall  f1-score   support\n'
#             '\n'
#             '           0       0.94      0.93      0.93       806\n'
#             '           1       0.87      0.86      0.86       808\n'
#             '           2       0.85      0.87      0.86       799\n'
#             '\n'
#             '    accuracy                           0.89      2413\n'
#             '   macro avg       0.89      0.89      0.89      2413\n'
#             'weighted avg       0.89      0.89      0.89      2413\n',
#   'time': '0:22:40.389004'},
#  {'bs': 16,
#   'epoch': 25,
#   'history': {'loss': [0.5207726919134847,
# ...

# %%
with open('indolem-indobert-gs/indolem_gs_result.pkl', 'rb') as f:
    data = pickle.load(f)

pprint(data)
# Out:
# [{'bs': 16,
#   'epoch': 5,
#   'history': {'loss': [0.5720315185052897,
#                        0.31969951878429625,
#                        0.19015686372842858,
#                        0.12047050822544478,
#                        0.09990701330156108]},
#   'lr': 2e-05,
#   'name': 'indolem-indobert-gs-0.pkl',
#   'report': '              precision    recall  f1-score   support\n'
#             '\n'
#             '           0       0.95      0.94      0.95       806\n'
#             '           1       0.88      0.89      0.89       808\n'
#             '           2       0.88      0.88      0.88       799\n'
#             '\n'
#             '    accuracy                           0.90      2413\n'
#             '   macro avg       0.90      0.90      0.90      2413\n'
#             'weighted avg       0.90      0.90      0.90      2413\n',
#   'time': '0:22:38.081481'},
#  {'bs': 16,
#   'epoch': 25,
#   'history': {'loss': [0.5832416346917549,
# ...

# %%
obj = pickle.load(open('indonlu-indobert-gs/indonlu_gs_result.pkl', 'rb'))

with open("indonlu-indobert-gs/indonlu_gs_result.txt", "a") as f:
    pprint(obj, stream=f)

# %%
obj2 = pickle.load(open('indolem-indobert-gs/indolem_gs_result.pkl', 'rb'))

with open("indolem-indobert-gs/indolem_gs_result.txt", "a") as f:
    pprint(obj2, stream=f)
